# %% [markdown]
# ## Business Infos

# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt

# %%
file = open("category_search.pickle",'rb')
data = pickle.load(file)
file.close()

# %%
data
# Out:
#                            id                                     alias  \
# 0      LLwMMNR2X84qnYWEjL8iJQ     atelier-de-impressão-cadigital-lisboa
# 1      FcXRFTG4mH9n_0K3GQXR9w                           feel-rio-lisboa
# 2      OC-bzpOIFvqjmk-3JMu23Q                               bowl-lisboa
# 3      my5oNNumojOxC0BbCXRxhw                    luvaria-ulisses-lisboa
# 4      0DyhgfjZBeyPbU0VxdHkZg                 modistas-de-lisboa-lisboa
# ...                       ...                                       ...
# 19200  OPyuozDU0aHezmVm4xaovA                          mandala-odivelas
# 19201  PuxDgAdqgTpbsZM0KGet_g  centro-do-yoga-do-rato-associação-lisboa
# 19202  Gcr6rYUEIWJDQpaxH2TteQ              dr-bernard-costa-da-caparica
# 19203  D2tLycuYeDKNnNbVcgZLGw       jardim-zoológico-de-lisboa-lisboa-2
# 19204  nX1YCgvrOmYO_R1VzYTMVw                             animax-lisboa
#
#                                     name  \
# 0       Atelier de Impressão - Cadigital
# ...

# %%
data = data.drop_duplicates('id')

# %%
data
# Out:
#                            id                                  alias  \
# 0      LLwMMNR2X84qnYWEjL8iJQ  atelier-de-impressão-cadigital-lisboa
# 1      FcXRFTG4mH9n_0K3GQXR9w                        feel-rio-lisboa
# 2      OC-bzpOIFvqjmk-3JMu23Q                            bowl-lisboa
# 3      my5oNNumojOxC0BbCXRxhw                 luvaria-ulisses-lisboa
# 4      0DyhgfjZBeyPbU0VxdHkZg              modistas-de-lisboa-lisboa
# ...                       ...                                    ...
# 19179  _g2EOpB6NqRJtBMDYCkuHA                          muse-lisboa-2
# 19184  TMmDKbsgV9Ym2TGKo9gblQ                       casa-mami-lisboa
# 19185  VBQVXDzvEp4NUHX6wzkiXA                      fashionrio-lisboa
# 19187  OqJ6DdCA8C7Xq1BjhAOFQA                          sednoc-lisboa
# 19188  hPjtzncV8t81AUqrT2h06w                         egzotis-lisboa
#
#                                    name  \
# 0      Atelier de Impressão - Cadigital
# 1                              Feel Rio
# ...

# %%
cats = pd.json_normalize(data['categories'])

# %%
categories_0 = pd.json_normalize(cats[0])

# %%
categories_0
# Out:
#                   alias                   title
# 0             copyshops       Printing Services
# 1             brazilian               Brazilian
# 2             juicebars  Juice Bars & Smoothies
# 3           accessories             Accessories
# 4     sewingalterations    Sewing & Alterations
# ...                 ...                     ...
# 8491        womenscloth        Women's Clothing
# 8492        womenscloth        Women's Clothing
# 8493        womenscloth        Women's Clothing
# 8494        womenscloth        Women's Clothing
# 8495        womenscloth        Women's Clothing
#
# [8496 rows x 2 columns]

# %%
categories_1 = pd.json_normalize(cats[1])

# %%
categories_1
# Out:
#             alias                   title
# 0      3dprinting             3D Printing
# 1       juicebars  Juice Bars & Smoothies
# 2       acaibowls              Acai Bowls
# 3             NaN                     NaN
# 4     accessories             Accessories
# ...           ...                     ...
# 8491          NaN                     NaN
# 8492          NaN                     NaN
# 8493          NaN                     NaN
# 8494          NaN                     NaN
# 8495          NaN                     NaN
#
# [8496 rows x 2 columns]

# %%
data['rating'].mean()
# Out:
# 3.7454096045197742

# %%
plt.hist(data['rating'])
# Out:
# (array([2.000e+00, 0.000e+00, 1.170e+02, 1.700e+01, 1.720e+02, 1.990e+02,
#         1.926e+03, 1.375e+03, 2.689e+03, 1.999e+03]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
data.describe()
# Out:
#        review_count      rating      distance
# count   8496.000000  8496.00000  8.496000e+03
# mean       4.552848     3.74541  5.252025e+03
# std       17.982937     0.78900  1.364840e+05
# min        0.000000     0.00000  1.289164e+02
# 25%        1.000000     3.00000  2.280956e+03
# 50%        2.000000     4.00000  3.354329e+03
# 75%        3.000000     4.00000  4.140098e+03
# max      928.000000     5.00000  1.257892e+07

# %% [markdown]
# ### New csv that contains all business id's with >0 reviews

# %%
data.sort_values('review_count', ascending = True) #10051
# Out:
#                            id                              alias  \
# 10051  dfCJ_3O3E0ZuA3Y4uE5YIw  centro-de-saúde-da-graça-lisboa-2
# 4625   rfMAa-BiRgvybNSD8X-0BQ         time-tea-e-coffee-lisboa-2
# 6891   IheVkUbZurXFMh-vhO9bUA      luis-brazão-decorações-lisboa
# 6890   3NX71AxLxczzAxiX0RMi4Q        armetal-equipamentos-lisboa
# 6885   kZH5pVchcBnKFNxBxo-f0g                      gamosa-lisboa
# ...                       ...                                ...
# 615    8MkNHKc-k3YY3yhG16a_AQ         aeroporto-de-lisboa-lisboa
# 1614   4jUlziXrWB4nmzWqeo7Skg               manteigaria-lisboa-3
# 1897   9j9e8taae0HZHuLNbOILQg           cervejaria-ramiro-lisboa
# 15018  ADbWtlEmjlhYTBkoRq7EXQ           time-out-market-lisboa-2
# 1615   zz18h1-m5sGlM679s4u8XQ          pastéis-de-belém-lisboa-6
#
#                            name  \
# 10051  Centro de Saúde da Graça
# 4625          Time Tea & Coffee
# 6891     Luis Brazão Decorações
# 6890       Armetal-Equipamentos
# ...

# %%
new_data = data.drop(index=4625)

# %%
new_data =data.drop(index=10051)

# %%
new_data.to_csv('saved_data.csv')

# %%
with open("lisbon_businesses.pickle", "wb") as f:
        pickle.dump(new_data, f)

# %% [markdown]
# ## Reviews

# %%
file = open("reviews.pickle",'rb')
data = pickle.load(file)
file.close()

# %%
data
# Out:
#                  business_id  \
# 0     LLwMMNR2X84qnYWEjL8iJQ
# 1     FcXRFTG4mH9n_0K3GQXR9w
# 2     OC-bzpOIFvqjmk-3JMu23Q
# 3     my5oNNumojOxC0BbCXRxhw
# 4     0DyhgfjZBeyPbU0VxdHkZg
# ...                      ...
# 4985  Z8JST03CJ1jMh5CkAORJrQ
# 4986  PBHGX__vUi_clHVKe-MPmA
# 4987  DYg4qsu0xMUVBTaImcOJJQ
# 4988  9WbmEfTUpZEjKHfZxVzBNA
# 4989  e3LH0etzSDr9cP29u4jxmg
#
#                                                response
# 0     {'reviews': [], 'total': 1, 'possible_language...
# 1     {'reviews': [{'id': 'aRt058EBVtgzQneA3aRV9w', ...
# 2     {'reviews': [{'id': 'Zr_CH5uslW3yIGiD6koCug', ...
# 3     {'reviews': [{'id': 'fhsZrT_fJCOo54QmLIx51w', ...
# 4     {'reviews': [{'id': 'KLKteZY-h_7wCcWD2VWzFw', ...
# ...                                                 ...
# 4985  {'reviews': [], 'total': 3, 'possible_language...
# 4986  {'reviews': [], 'total': 2, 'possible_language...
# 4987  {'reviews': [{'id': 'DPfpbCQWiDpr7BByBWXXcA', ...
# ...

# %%
file = open("reviews_2.pickle",'rb')
data_2 = pickle.load(file)
file.close()

# %%
data_2[1480:]
# Out:
#                  business_id  \
# 1480  094nUwvVGBtxwMHE8KpoPA
# 1481  nboAQsEqIjuRLdyGJTp1sQ
# 1482  cbb0qOr56Zfque6MBL7duw
# 1483  nRZGPfewJWPWptBRW8bvgg
# 1484  3tMEWuyVqfzIuyhfeJoS-Q
# ...                      ...
# 4985  8yA70vi3Y4V_CcBSdihH8Q
# 4986  OIA66bENsEZOWfGwdpirLA
# 4987  svEo_xmsyui17Qwe2mfMhg
# 4988  yDcLu3OZaZwmvspD0M1ziw
# 4989  nT7BRPZAi4Pg8DCEt7ca9g
#
#                                                response
# 1480  {'reviews': [], 'total': 2, 'possible_language...
# 1481  {'error': {'code': 'ACCESS_LIMIT_REACHED', 'de...
# 1482  {'error': {'code': 'ACCESS_LIMIT_REACHED', 'de...
# 1483  {'error': {'code': 'ACCESS_LIMIT_REACHED', 'de...
# 1484  {'error': {'code': 'ACCESS_LIMIT_REACHED', 'de...
# ...                                                 ...
# 4985  {'error': {'code': 'ACCESS_LIMIT_REACHED', 'de...
# 4986  {'error': {'code': 'ACCESS_LIMIT_REACHED', 'de...
# 4987  {'error': {'code': 'ACCESS_LIMIT_REACHED', 'de...
# ...

# %%
reviews = data.drop_duplicates('business_id')

# %%
reviews.tail(20)
# Out:
#                  business_id  \
# 4948  7XPmYcd7DE4Ob7gfEGshfQ
# 4949  -rxOwI2HyaFs9CU3u84f_A
# 4953  wqCKnybSjwQ7QZBXWLf2yw
# 4966  5a9L1lbcNg18RbZWDDoPLA
# 4967  6Nm_xCsR65ks2FlLDMNXQg
# 4968  9RqRT2jGHeZqUICwYzTczg
# 4969  KWsRB8FNuNUSIJNtuCMtlw
# 4972  WHZ4NLRX-1Hjr_Zq60Yw2w
# 4973  1D0xWH-t1tDDSfA5ZKollQ
# 4974  A5RS2FyAsbTk7bvPTrXDQg
# 4975  OUpv3xAlfI1OSx3Zd_5STw
# 4976  HApuA-UfLn6tTQfARytkXQ
# 4978  Bn5SwHqwWIw0-D6I5P9o2w
# 4982  OFBqbSKyhWSZ0LZaO_D5ZA
# 4983  Y_x65VzNx31_zNk2j_B3UA
# 4985  Z8JST03CJ1jMh5CkAORJrQ
# 4988  9WbmEfTUpZEjKHfZxVzBNA
# 4991  jIIsSz-j6FEx5bqY_p6f-Q
# 4992  DYke6U2zc-OSKFXYgF4cYg
# 4993  mLmiJhRKnCJJoXwwRxlGIg
#
#                                                response
# 4948  {'reviews': [], 'total': 2, 'possible_language...
# 4949  {'reviews': [{'id': 'YxrbViH65JQDubjrsP917g', ...
# 4953  {'reviews': [], 'total': 1, 'possible_language...
# 4966  {'reviews': [], 'total': 1, 'possible_language...
# ...

# %%
reviews = pd.json_normalize(data['response'])

# %%
reviews = pd.json_normalize(reviews['reviews'])

# %%
reviews_0 = pd.json_normalize(reviews[0])

# %%
reviews_1 = pd.json_normalize(reviews[1])

# %%
reviews_0.head(10)
# Out:
#                        id                                                url  \
# 0                     NaN                                                NaN
# 1  aRt058EBVtgzQneA3aRV9w  https://www.yelp.com/biz/feel-rio-lisboa?adjus...
# 2  Zr_CH5uslW3yIGiD6koCug  https://www.yelp.com/biz/bowl-lisboa?adjust_cr...
# 3  fhsZrT_fJCOo54QmLIx51w  https://www.yelp.com/biz/luvaria-ulisses-lisbo...
# 4  KLKteZY-h_7wCcWD2VWzFw  https://www.yelp.com/biz/modistas-de-lisboa-li...
# 5  BPT2eu2VN8FJY09hn8kCMA  https://www.yelp.com/biz/chicora%C3%A7%C3%A3o-...
# 6  Whbt5dKJKEv_KIfFNdToCQ  https://www.yelp.com/biz/garbags-lisboa?adjust...
# 7  32o--J8imQ4E-MVWtaiHgg  https://www.yelp.com/biz/cork-e-co-lisboa?adju...
# 8  se1I7aKM049e6WZRAbL1vA  https://www.yelp.com/biz/pedemeia-lisboa?adjus...
# 9  v_X8NRTHbdvnSF5Uitta7A  https://www.yelp.com/biz/louis-vuitton-lisboa?...
#
#                                                 text  rating  \
# ...

# %%
reviews = reviews.append(data_2)

# %%
reviews =reviews.drop_duplicates('business_id')

# %%
reviews = pd.json_normalize(reviews['response'])

# %%
reviews = pd.json_normalize(reviews['reviews'])

# %%
reviews_0 = pd.json_normalize(reviews[0])

# %%
reviews_0
# Out:
#                           id  \
# 0                        NaN
# 1     aRt058EBVtgzQneA3aRV9w
# 2     Zr_CH5uslW3yIGiD6koCug
# 3     fhsZrT_fJCOo54QmLIx51w
# 4     KLKteZY-h_7wCcWD2VWzFw
# ...                      ...
# 5614  huIrLcLyRpsbMSy0E96gzQ
# 5615  iAnTroTUZmKWHNjAMqcH5w
# 5616  ayufPlrT5T5Pc1712ozZsw
# 5617  1oXem8IpaeGFAp0xhit_FA
# 5618  qPLCyxdEivkE0xDajrhGnA
#
#                                                     url  \
# 0                                                   NaN
# 1     https://www.yelp.com/biz/feel-rio-lisboa?adjus...
# 2     https://www.yelp.com/biz/bowl-lisboa?adjust_cr...
# 3     https://www.yelp.com/biz/luvaria-ulisses-lisbo...
# 4     https://www.yelp.com/biz/modistas-de-lisboa-li...
# ...                                                 ...
# 5614  https://www.yelp.com/biz/restaurante-o-arco-li...
# 5615  https://www.yelp.com/biz/a-taberna-da-rua-das-...
# 5616  https://www.yelp.com/biz/cruzes-credo-lisboa?a...
# ...

# %% [markdown]
# Next step : locate position of 5618 in data

# %%
file = open("reviews_3.pickle",'rb')
data_3 = pickle.load(file)
file.close()

# %%
all_reviews = data_3.append(reviews)

# %%
all_reviews.drop_duplicates('business_id')
# Out:
#                  business_id  \
# 0     NJt44WUsusQRzHkZfFTuSg
# 1     kXkxLbdTmTiE_n1XVPh9Vw
# 2     JAxoyB3OdzAD8IzvHYIeAg
# 3     sL8V4fp8yo6SekFsSzvpMw
# 4     GTv78km28m438B4K37usEg
# ...                      ...
# 4979  XmHyupu2U0IgCV9I4DFQ7A
# 4980  E1bCMAZlh0kIQ_bY7dnSvA
# 4983  bHGu9J6KtvB5MGFNS8bZ9Q
# 4987  svEo_xmsyui17Qwe2mfMhg
# 4988  yDcLu3OZaZwmvspD0M1ziw
#
#                                                response    0    1    2
# 0     {'reviews': [{'id': 'sGHG19xzPLDus67m9lSSVA', ...  NaN  NaN  NaN
# 1     {'reviews': [], 'total': 1, 'possible_language...  NaN  NaN  NaN
# 2     {'reviews': [], 'total': 1, 'possible_language...  NaN  NaN  NaN
# 3     {'reviews': [], 'total': 1, 'possible_language...  NaN  NaN  NaN
# 4     {'reviews': [], 'total': 1, 'possible_language...  NaN  NaN  NaN
# ...                                                 ...  ...  ...  ...
# 4979  {'error': {'code': 'ACCESS_LIMIT_REACHED', 'de...  NaN  NaN  NaN
# ...
